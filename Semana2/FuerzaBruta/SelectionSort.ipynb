# %%
#Ordenar una lista por seleccion y mostrtala paso a paso
def sort_by_selection(lista):
    for i in range(len(lista)):
        minimo = i
        for j in range( i + 1, len(lista)):
            if lista[minimo] > lista[j]:
                minimo = j
        lista[i], lista[minimo] = lista[minimo], lista[i]
        print(lista)
    return lista

lista = [64, 25, 12, 22, 11]
print("Lista original: ", lista)
print("Lista ordenada: ", sort_by_selection(lista))
# Out:
# Lista original:  [64, 25, 12, 22, 11]
# [11, 25, 12, 22, 64]
# [11, 12, 25, 22, 64]
# [11, 12, 22, 25, 64]
# [11, 12, 22, 25, 64]
# [11, 12, 22, 25, 64]
# Lista ordenada:  [11, 12, 22, 25, 64]
